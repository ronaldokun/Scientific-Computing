# %%
print "hello world again again"
# Out:
# hello world again again

# %%
from publish_snapshot import publish_snapshot

# %%
publish_snapshot("Jeff Hussmann 01-17-14 Storytelling example.ipynb")

# %%
publish_snapshot("Untitled0.ipynb")
